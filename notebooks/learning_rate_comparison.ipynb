# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

from matplotlib import pyplot as plt
import numpy as np
from blackjack.learners import Sarsa
from blackjack import visualize
from blackjack.common import AGENT_HANDS, ACTIONS

# %%
learner = Sarsa(name='sarsa', gamma=1., alpha=0.01)

# %%
learner.train_and_evaluate(n_episodes=int(1e5));

# %%
visualize.plot_eval_reward(learner)
