# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

from matplotlib import pyplot as plt
import numpy as np
from blackjack.learners import MonteCarlo

# %%
learner = MonteCarlo(epsilon=0.1, window_size=1000, gamma=0.9)
learner.train_and_evaluate(n_episodes=int(1e5))

# %%
plt.errorbar(*zip(*learner.evaluations))
plt.xlabel('Number of Training Episodes')
plt.ylabel('Estimated Mean Reward')
plt.gca().set_xscale('log')
plt.show()
