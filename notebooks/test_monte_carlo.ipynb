# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

from matplotlib import pyplot as plt
import numpy as np
from blackjack.learners import MonteCarlo
from blackjack import visualize
from blackjack.common import AGENT_HANDS, ACTIONS

# %%
learner = MonteCarlo(epsilon=0.1, window_size=1000, gamma=0.9, name='mc')
learner.train_and_evaluate(n_episodes=int(1e6))

# %%
visualize.plot_eval_reward(learner)

# %%
visualize.plot_strategy_card(learner)

# %%
visualize.print_strategy_card(learner)
# Out:
#      2 3 4 5 6 7 8 9 10A
# A 21 S S S S S S S S S S
# A 20 S S S S S S S S S S
# A 19 S S S S S S S S S S
# A 18 H S S S S S S S H S
# A 17 H H H S S H H H H H
# A 16 H H H H H H H H H H
# A 15 H H H H H H H H H H
# A 14 H H H H H H H H H H
# A 13 H H H H H H H H H H
# A 12 S H H H H H H H H S
#   21 S S S S S S S S S S
#   20 S S S S S S S S S S
#   19 S S S S S S S S S S
#   18 S S S S S S S S S S
#   17 S S S S S S S S S S
#   16 S S S S S S H S S H
#   15 S S S S S H H H H H
#   14 S S S S S H H H H H
#   13 S S S S S H H H H H
#   12 H S S S S H H H H H
